# %%
# %pip install llama-index-embeddings-openai
# %pip install llama-index-vector-stores-pinecone
# %pip install llama-index-llms-openai
# Out:
# Requirement already satisfied: llama-index-embeddings-openai in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (0.1.11)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-embeddings-openai) (0.10.56)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.5.0)
# Requirement already satisfied: httpx in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.24.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.35.7)
# Requirement already satisfied: pandas in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.4.2)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.0.3)
# Requirement already satisfied: click in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.5.15)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.10.17)
# Requirement already satisfied: sniffio in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: certifi in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: idna in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-vector-stores-pinecone in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (0.1.8)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.11.post1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-vector-stores-pinecone) (0.10.56)
# Requirement already satisfied: pinecone-client<4.0.0,>=3.0.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-vector-stores-pinecone) (3.0.3)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2024.5.0)
# Requirement already satisfied: httpx in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.24.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.35.7)
# Requirement already satisfied: pandas in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (8.4.2)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.16.0)
# Requirement already satisfied: certifi>=2019.11.17 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pinecone-client<4.0.0,>=3.0.2->llama-index-vector-stores-pinecone) (2024.6.2)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pinecone-client<4.0.0,>=3.0.2->llama-index-vector-stores-pinecone) (2.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (4.0.3)
# Requirement already satisfied: click in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (8.1.7)
# Requirement already satisfied: joblib in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2024.5.15)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.10.17)
# Requirement already satisfied: sniffio in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.3.1)
# Requirement already satisfied: httpcore==1.* in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.0.5)
# Requirement already satisfied: idna in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.0.3)
# Requirement already satisfied: colorama in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-vector-stores-pinecone) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (0.1.26)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.24 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-llms-openai) (0.10.56)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.5.0)
# Requirement already satisfied: httpx in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.24.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.35.7)
# Requirement already satisfied: pandas in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (8.4.2)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.0.3)
# Requirement already satisfied: click in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (8.1.7)
# Requirement already satisfied: joblib in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.5.15)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.10.17)
# Requirement already satisfied: sniffio in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: certifi in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.5)
# Requirement already satisfied: idna in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.0.3)
# Requirement already satisfied: colorama in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.24->llama-index-llms-openai) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install llama-index
# Out:
# Requirement already satisfied: llama-index in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (0.10.56)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.2.9)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.12)
# Requirement already satisfied: llama-index-core==0.10.56 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.10.56)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.11)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.2.5)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.13 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.26)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.8)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.30)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.56->llama-index) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (2024.5.0)
# Requirement already satisfied: httpx in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (1.24.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (1.35.7)
# Requirement already satisfied: pandas in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (8.4.2)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.56->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.9 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (0.0.9)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.2.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-llama-parse>=0.1.2->llama-index) (0.4.9)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.56->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.56->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.56->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.56->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.56->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.56->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from llama-cloud>=0.0.9->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (1.10.17)
# Requirement already satisfied: anyio in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.56->llama-index) (4.4.0)
# Requirement already satisfied: certifi in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.56->llama-index) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.56->llama-index) (1.0.5)
# Requirement already satisfied: idna in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.56->llama-index) (3.7)
# Requirement already satisfied: sniffio in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.56->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.56->llama-index) (0.14.0)
# Requirement already satisfied: click in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.56->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.56->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.56->llama-index) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core==0.10.56->llama-index) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.56->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.56->llama-index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.56->llama-index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core==0.10.56->llama-index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.56->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from dataclasses-json->llama-index-core==0.10.56->llama-index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.56->llama-index) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.56->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.56->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from anyio->httpx->llama-index-core==0.10.56->llama-index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.56->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\bobth\anaconda3\envs\mchatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.56->llama-index) (1.16.0)

# %%
# !pip -q install python-dotenv pinecone-client llama-index pymupdf
